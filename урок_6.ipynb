# %% [markdown]
# <a href="https://colab.research.google.com/github/Proekkt/Pyton/blob/main/%D1%83%D1%80%D0%BE%D0%BA_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.optimize import fsolve
import matplotlib.pyplot as plt
x=np.linspace(-10,10,100)
y=x**2+5*x*np.sin(x)-10
def f(x):
  return(x**2+5*5*np.sin(x)-10)
x1=fsolve(f,-5)
plt.plot(x,y,"r")
plt.grid()
plt.scatter(x1,0,c="b")
print(x1)
# Out:
# [-3.14576034]

# %%
import numpy as np
import math
import matplotlib.pyplot as plt
x=np.linspace(-10,10,100)
y=x**2+5*x*np.sin(x)-10
f=x**2
from scipy.optimize import fsolve
def tochki(x):
  return(x**2+5*x*np.sin(x)-10)
p=fsolve(tochki,-5)
x1=fsolve(tochki,-2)
print('res=',fsolve(tochki,-5))
plt.scatter([fsolve(tochki,-5),
             fsolve(tochki,-3),
             fsolve(tochki,-1),
             fsolve(tochki,1),
             fsolve(tochki,3),
             fsolve(tochki,5)],
            [0,0,0,0,0,0],c='r')
plt.plot(x,y,'#0a0a0a')
plt.title("Function 27.10")
plt.xlabel("Ось х")
plt.ylabel("Ось y")
plt.grid()
plt.show()
# Out:
# res= [-5.46801798]
